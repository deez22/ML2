# %%
print("hi")
import numpy as np
import matplotlib.pyplot as plt
# Out:
# hi

# %%
## 4.

# input parameters

# %%
#generate random x samples
def generate_x(N, dimension):
    norm = np.random.normal
    normal_deviates = norm(size=(dimension, N))

    radius = np.sqrt((normal_deviates**2).sum(axis=0))
    x = normal_deviates/radius

    fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
    ax.scatter(*x)
    ax.set_aspect('auto')
    plt.show()
    return x

# %%
# calculate y
def generate_y(x, N, sigma):
    ones_array = np.ones(d).T
    y_first = np.power(0.25+np.power((ones_array*x),2),-1)
    y_second = np.random.normal(0, sigma, N)
    y = y_first + y_second
    return y

# %%
N_train = 200
N_test = 50
#dim = 2
d = 5
sigma = 2

x_train = generate_x(N_train, dimension=d)
y_train = generate_y(x_train, N_train, sigma=sigma)

x_test = generate_x(N_test, dimension=d)
y_test = generate_y(x_test, N_test, sigma=sigma)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2e78e2bf3891> in <module>
#       6
#       7 x_train = generate_x(N_train, dimension=d)
# ----> 8 y_train = generate_y(x_train, N_train, sigma=sigma)
#       9
#      10 x_test = generate_x(N_test, dimension=d)
#
# <ipython-input-27-a11ddb119847> in generate_y(x, N, sigma)
#       2 def generate_y(x, N, sigma):
#       3     ones_array = np.ones(d)
# ----> 4     y_first = np.power(0.25+np.power((ones_array*x),2),-1)
#       5     y_second = np.random.normal(0, sigma, N)
#       6     y = y_first + y_second
#
# ValueError: operands could not be broadcast together with shapes (5,) (5,200)

# %%
M = 50
